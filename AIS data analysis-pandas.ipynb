# %%
#Run this cell to move the files to /shared-data - only need to run for the first time
# !mv aisdk_20181102.csv /shared-data/ais_data/aisdk_20181102.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/shared-data/ais_data/aisdk_20181102.csv', sep=',', index_col=False)

# %%
df
# Out:
#                   # Timestamp Type of mobile       MMSI   Latitude  \
# 0         02/11/2018 00:00:00        Class A  219001182  55.822560
# 1         02/11/2018 00:00:00        Class A  212963000  58.273420
# 2         02/11/2018 00:00:00        Class A  220544000  57.118648
# 3         02/11/2018 00:00:00        Class A  538005698  56.732973
# 4         02/11/2018 00:00:00        Class A  311646000  58.046110
# ...                       ...            ...        ...        ...
# 10868971  02/11/2018 23:59:58        Class A  245169000  55.370420
# 10868972  02/11/2018 23:59:58   Base Station    2190065  91.000000
# 10868973  02/11/2018 23:59:58        Class A  244850116  54.425762
# 10868974  02/11/2018 23:59:58        Class A  219230000  56.043595
# 10868975  02/11/2018 23:59:58        Class A  219019804  57.592267
#
#            Longitude     Navigational status  ROT   SOG    COG  Heading  ...  \
# 0          10.063892  Under way using engine  0.0   0.0  272.0    272.0  ...
# ...

# %%
df.dtypes
# Out:
# # Timestamp                        object
# Type of mobile                     object
# MMSI                                int64
# Latitude                          float64
# Longitude                         float64
# Navigational status                object
# ROT                               float64
# SOG                               float64
# COG                               float64
# Heading                           float64
# IMO                                object
# Callsign                           object
# Name                               object
# Ship type                          object
# Cargo type                         object
# Width                             float64
# Length                            float64
# Type of position fixing device     object
# Draught                           float64
# Destination                        object
# ETA                                object
# Data source type                   object
# ...

# %%
df.count()
# Out:
# # Timestamp                       10868976
# Type of mobile                    10868976
# MMSI                              10868976
# Latitude                          10868976
# Longitude                         10868976
# Navigational status               10868976
# ROT                                7553736
# SOG                               10260945
# COG                                9884442
# Heading                            8627321
# IMO                               10868976
# Callsign                          10133273
# Name                              10243557
# Ship type                         10868976
# Cargo type                         1934918
# Width                              9848463
# Length                             9857381
# Type of position fixing device    10868976
# Draught                            8372494
# Destination                        7966358
# ETA                                6931085
# Data source type                  10868976
# ...

# %%
df=df.loc[df['MMSI'].isin(['212963000','219000751','219015591','305837000','311646000'])]

# %%
df.rename(columns={"# Timestamp": 'Timestamp'}, inplace=True)
df1=df[['Timestamp','MMSI','Latitude','Longitude']]
# Out:
# /opt/conda/envs/rapids/lib/python3.7/site-packages/pandas/core/frame.py:4301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df1.count()
# Out:
# Timestamp    38196
# MMSI         38196
# Latitude     38196
# Longitude    38196
# dtype: int64

# %%
df1
# Out:
#                     Timestamp       MMSI   Latitude  Longitude
# 1         02/11/2018 00:00:00  212963000  58.273420  10.959500
# 4         02/11/2018 00:00:00  311646000  58.046110  10.192865
# 62        02/11/2018 00:00:00  219000751  55.248292  14.836152
# 154       02/11/2018 00:00:01  305837000  54.597698  12.253178
# 441       02/11/2018 00:00:03  305837000  54.597563  12.253113
# ...                       ...        ...        ...        ...
# 10868265  02/11/2018 23:59:53  305837000  54.668167  10.977860
# 10868513  02/11/2018 23:59:55  305837000  54.668243  10.977648
# 10868755  02/11/2018 23:59:57  305837000  54.668318  10.977435
# 10868896  02/11/2018 23:59:58  212963000  57.776577  10.380972
# 10868934  02/11/2018 23:59:58  219015591  57.213833   9.686700
#
# [38196 rows x 4 columns]

# %%
df1.to_csv('results.csv')
