# %%
#Run this cell to copy data to /shared-data folder - only need to run for the first time
# !mkdir -p /shared-data/datasets/AISdata
# !cp datasets/aisdk_20181102.csv /shared-data/datasets/AISdata

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/shared-data/datasets/AISdata/aisdk_20181102.csv', sep=',', index_col=False)

# %%
df
# Out:
#          # Timestamp Type of mobile       MMSI   Latitude  Longitude  \
# 0       2/11/18 0:00        Class A  219001182  55.822560  10.063892
# 1       2/11/18 0:00        Class A  212963000  58.273420  10.959500
# 2       2/11/18 0:00        Class A  220544000  57.118648   8.595348
# 3       2/11/18 0:00        Class A  538005698  56.732973  11.885740
# 4       2/11/18 0:00        Class A  311646000  58.046110  10.192865
# ...              ...            ...        ...        ...        ...
# 499994  2/11/18 1:08   Base Station    2190076  55.674632   9.501953
# 499995  2/11/18 1:08        Class A  212503000  55.234358  12.635925
# 499996  2/11/18 1:08        Class A  219798000  56.370425   8.119983
# 499997  2/11/18 1:08        Class A  211519000  54.682360   9.992160
# 499998  2/11/18 1:08        Class A  219006005  57.716270  10.586553
#
#            Navigational status  ROT   SOG    COG  Heading  ... Length  \
# ...

# %%
df.dtypes
# Out:
# # Timestamp                        object
# Type of mobile                     object
# MMSI                                int64
# Latitude                          float64
# Longitude                         float64
# Navigational status                object
# ROT                               float64
# SOG                               float64
# COG                               float64
# Heading                           float64
# IMO                                object
# Callsign                           object
# Name                               object
# Ship type                          object
# Cargo type                         object
# Width                             float64
# Length                            float64
# Type of position fixing device     object
# Draught                           float64
# Destination                        object
# ETA                                object
# Data source type                   object
# ...

# %%
df.count()
# Out:
# # Timestamp                       499999
# Type of mobile                    499999
# MMSI                              499999
# Latitude                          499999
# Longitude                         499999
# Navigational status               499999
# ROT                               361870
# SOG                               469813
# COG                               450676
# Heading                           397685
# IMO                               499999
# Callsign                          436339
# Name                              441275
# Ship type                         499999
# Cargo type                         93369
# Width                             423221
# Length                            423628
# Type of position fixing device    499999
# Draught                           358554
# Destination                       341124
# ETA                               301208
# Data source type                  499999
# A                                 422192
# ...

# %%
df=df.loc[df['MMSI'].isin(['212963000','219000751','219015591','305837000','311646000'])]

# %%
df.rename(columns={"# Timestamp": 'Timestamp'}, inplace=True)
df1=df[['Timestamp','MMSI','Latitude','Longitude']]

# %%
df1.count()
# Out:
# Timestamp    4093
# MMSI         4093
# Latitude     4093
# Longitude    4093
# dtype: int64

# %%
df1
# Out:
#            Timestamp       MMSI   Latitude  Longitude
# 1       2/11/18 0:00  212963000  58.273420  10.959500
# 4       2/11/18 0:00  311646000  58.046110  10.192865
# 62      2/11/18 0:00  219000751  55.248292  14.836152
# 154     2/11/18 0:00  305837000  54.597698  12.253178
# 441     2/11/18 0:00  305837000  54.597563  12.253113
# ...              ...        ...        ...        ...
# 499612  2/11/18 1:08  219015591  57.213833   9.686700
# 499614  2/11/18 1:08  212963000  58.015165  11.128608
# 499681  2/11/18 1:08  305837000  54.415167  11.962613
# 499841  2/11/18 1:08  219000751  55.248252  14.836177
# 499902  2/11/18 1:08  305837000  54.415082  11.962412
#
# [4093 rows x 4 columns]

# %%
df1.to_csv('/shared-data/datasets/AISdata/results.csv')
